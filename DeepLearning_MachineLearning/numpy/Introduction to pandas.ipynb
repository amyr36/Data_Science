# %%
import pandas as pd

# %%
cars = ["bmw", "benz", "ferrari", "206"]
colors = ["white", "blue", "red", "green"]

# %%
car_series = pd.Series(cars, index=[1, 3, 5, 7])
car_series
# Out:
# 1        bmw
# 3       benz
# 5    ferrari
# 7        206
# dtype: object

# %%
colors_series = pd.Series(colors)
colors_series
# Out:
# 0    white
# 1     blue
# 2      red
# 3    green
# dtype: object

# %%
car_series.loc[3]
# Out:
# 'benz'

# %%
car_series.iloc[3]
# Out:
# '206'

# %%
df = pd.DataFrame({"car name": cars, "color": colors})
df
# Out:
#   car name  color
# 0      bmw  white
# 1     benz   blue
# 2  ferrari    red
# 3      206  green

# %%
df.to_csv("my-cars.csv", index=False)

# %%
my_car = pd.read_csv("my-cars.csv")
my_car
# Out:
#   car name  color
# 0      bmw  white
# 1     benz   blue
# 2  ferrari    red
# 3      206  green

# %%
df["car name"]
# Out:
# 0        bmw
# 1       benz
# 2    ferrari
# 3        206
# Name: car name, dtype: object

# %%
df.color
# Out:
# 0    white
# 1     blue
# 2      red
# 3    green
# Name: color, dtype: object

# %%
df.columns
# Out:
# Index(['car name', 'color'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.head(2)
# Out:
#   car name  color
# 0      bmw  white
# 1     benz   blue

# %%
car.tail(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 car.tail(2)
#
# NameError: name 'car' is not defined

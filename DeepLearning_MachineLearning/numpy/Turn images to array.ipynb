# %%
from matplotlib.image import imread

# %%
<img src="images/1.jpg" width=150 height=200>

# %%
my_frist_image = imread("images/1.jpg")
type(my_frist_image)
# Out:
# numpy.ndarray

# %%
my_frist_image.shape, my_frist_image.ndim, my_frist_image.size
# Out:
# ((1800, 2880, 3), 3, 15552000)

# %%
my_frist_image[:1]
# Out:
# array([[[ 41,  44,  77],
#         [ 41,  44,  77],
#         [ 41,  44,  77],
#         ...,
#         [175,  95, 108],
#         [175,  95, 108],
#         [175,  95, 108]]], shape=(1, 2880, 3), dtype=uint8)

# %% [markdown]
# <img src="images/2.png" width=150 height=200>

# %%
my_second_image = imread("images/2.png")
type(my_second_image)
# Out:
# numpy.ndarray

# %%
my_second_image.shape, my_second_image.ndim, my_second_image.size
# Out:
# ((1080, 1920, 4), 3, 8294400)

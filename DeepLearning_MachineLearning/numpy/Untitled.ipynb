# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
a.shape
# Out:
# (3,)

# %%
a.ndim
# Out:
# 1

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.size
# Out:
# 3

# %%
b = np.array([[1, 2, 3], [9, 7, 6]])
b
# Out:
# array([[1, 2, 3],
#        [9, 7, 6]])

# %%
b.shape
# Out:
# (2, 3)

# %%
b.ndim
# Out:
# 2

# %%
b.size
# Out:
# 6

# %%
b = np.array([[1, 2, 3], [9, 7, 6]])
a = np.array([[1, 2, 3], [12, 67, 9]])
c = np.array([a, b])
c
# Out:
# array([[[ 1,  2,  3],
#         [12, 67,  9]],
#
#        [[ 1,  2,  3],
#         [ 9,  7,  6]]])

# %%
c.shape
# Out:
# (2, 2, 3)

# %%
c.dtype
# Out:
# dtype('int64')

# %%
c.ndim
# Out:
# 3

# %%
c.ndim
# Out:
# 3

# %%
type(c)
# Out:
# numpy.ndarray

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [5, 3, -1, 2, 6]
y = [14, 6, -5.5, 3.5, 18]
x, y
# Out:
# ([5, 3, -1, 2, 6], [14, 6, -5.5, 3.5, 18])

# %%
X, Y, XiYi, Xi2 = 0, 0, 0, 0
n = len(x)
for i in range(n):
    X = X + x[i]
    Y = Y + y[i]
    XiYi = XiYi + x[i] * y[i]
    Xi2 = Xi2 + x[i] ** 2
print(X, Y, n, XiYi, Xi2)
# Out:
# 15 36.0 5 208.5 75

# %%
w1 = (n * XiYi - X * Y) / (n * Xi2 - X**2)
w1
# Out:
# 3.35

# %%
w0 = (Y - w1*X) / n
w0
# Out:
# -2.85

# %%
height = np.array([178, 180, 190, 173]).reshape(-1, 1)
weight = np.array([60, 67, 85, 66])
model = LinearRegression().fit(height, weight)
b = model.intercept_
a = model.coef_

# %%
predicted_weight = model.predict([[183]])
predicted_weight[0]
# Out:
# np.float64(73.07364975450082)

# %%
plt.scatter(height, weight, color='blue', label='Data points')
plt.plot(height, model.predict(height), color='red', label='Regression line')
plt.show()

# %%
weight_pred = model.predict(height)
residuals = weight - weight_pred
mae = mean_absolute_error(weight, weight_pred)
mse = mean_squ

# %%
# Out:
# 4.3756137479541835
